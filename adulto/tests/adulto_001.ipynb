# %%
"""
Programa adulto
Descrição: Este programa pergunta a idade de uma pessoa. Se a pessoa for maior do que 18 anos, o programa imprime 
na tela "Oi! Você é uma adulto."
Autor: Mariana Meller Jost
Data: 24/03/2026
Versão: 0.0.1

"""
# Out:
# '\nPrograma adulto\nDescrição: Este programa pergunta a idade de uma pessoa. Se a pessoa for maior do que 18 anos, o programa imprime \nna tela "Oi! Você é uma adulto."\nAutor: Mariana Meller Jost\nData: 24/03/2026\nVersão: 0.0.1\n\n'

# %%
# Alocação de memória 

idade = 0

texto = ""

# %%
# Entrada de dados

idade = int(input("\nQual é a sua idade?"))
# Out:
# Qual é a sua idade? 13

# %%
# Processamento de dados 

if idade >= 18:
    texto = "Oi! Você é um adulto."

# %%
# Saída de dados 

print(texto)
